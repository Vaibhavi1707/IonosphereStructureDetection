# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
ionosphere_df = pd.read_csv('datasets/ionosphere.csv')

# %%
len(ionosphere_df)
# Out:
# 351

# %% [markdown]
# # Data preprocessing
#
# In this dataset, we need to have only 2 kinds of preprocessing:
# - Removing null values
# - Removing duplicate rows

# %% [markdown]
# ## Checking for null values

# %%
print("Total number of rows", len(ionosphere_df))
ionosphere_df.isna().sum()
# Out:
# ('Total number of rows', 351)
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     0
# 7     0
# 8     2
# 9     1
# 10    0
# 11    1
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    0
# 18    0
# 19    1
# 20    0
# 21    0
# 22    0
# 23    0
# 24    3
# 25    0
# 26    2
# 27    2
# 28    0
# 29    0
# 30    2
# 31    1
# 32    0
# 33    0
# 34    0
# dtype: int64

# %% [markdown]
# In the above output, we see that the number of missing valued rows are very less than the total number of rows. Hence, we drop all rows with any null value.

# %%
ionosphere_df = ionosphere_df.dropna()

# %%
print("Size of dataset", len(ionosphere_df))
# Out:
# ('Size of dataset', 331)

# %% [markdown]
# ## Removing duplicate rows

# %%
ionosphere_df = ionosphere_df.drop_duplicates()

# %%
print("The final dataset size is", len(ionosphere_df))
# Out:
# ('The final dataset size is', 330)

# %%
ionosphere_df
# Out:
#      0  1        2        3        4        5        6        7        8  \
# 0    1  0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1    1  0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2    1  0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3    1  0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4    1  0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
# 5    1  0  0.02337 -0.00592 -0.09924 -0.11949 -0.00763 -0.11824  0.14706
# 6    1  0  0.97588 -0.10602  0.94601 -0.20800  0.92806 -0.28350  0.85996
# 7    0  0  0.00000  0.00000  0.00000  0.00000  1.00000 -1.00000  0.00000
# 8    1  0  0.96355 -0.07198  1.00000 -0.14333  1.00000 -0.21313  1.00000
# 9    1  0 -0.01864 -0.08459  0.00000  0.00000  0.00000  0.00000  0.11470
# 10   1  0  1.00000  0.06655  1.00000 -0.18388  1.00000 -0.27320  1.00000
# 11   1  0  1.00000 -0.54210  1.00000 -1.00000  1.00000 -1.00000  1.00000
# 12   1  0  1.00000 -0.16316  1.00000 -0.10169  0.99999 -0.15197  1.00000
# 13   1  0  1.00000 -0.86701  1.00000  0.22280  0.85492 -0.39896  1.00000
# 14   1  0  1.00000  0.07380  1.00000  0.03420  1.00000 -0.05563  1.00000
# 15   1  0  0.50932 -0.93996  1.00000  0.26708 -0.03520 -1.00000  1.00000
# 16   1  0  0.99645  0.06468  1.00000 -0.01236  0.97811  0.02498  0.96112
# 17   0  0  0.00000  0.00000 -1.00000 -1.00000  1.00000  1.00000 -1.00000
# 18   1  0  0.67065  0.02528  0.66626  0.05031  0.57197  0.18761  0.08776
# 19   0  0  1.00000 -1.00000  0.00000  0.00000  0.00000  0.00000  1.00000
# 20   1  0  1.00000 -0.00612  1.00000 -0.09834  1.00000 -0.07649  1.00000
# 21   0  0  1.00000  1.00000  0.00000  0.00000  0.00000  0.00000 -1.00000
# 22   1  0  0.96071  0.07088  1.00000  0.04296  1.00000  0.09313  0.90169
# 23   0  0 -1.00000  1.00000  0.00000  0.00000  0.00000  0.00000 -1.00000
# 24   1  0  1.00000 -0.06182  1.00000  0.02942  1.00000 -0.05131  1.00000
# 25   1  0  1.00000  0.57820  1.00000 -1.00000  1.00000 -1.00000  1.00000
# 337  0.20359  0.70555  0.54852   g
# 338  0.20540  0.13376  0.26422   g
# 339  0.76764 -0.18533  0.74356   g
# 340  0.16794 -0.30153 -0.33588   g
# 341  0.08126  0.97247  0.08616   g
# 342 -0.04220  0.78439  0.01214   g
# 343 -0.08637  0.28943 -0.08300   g
# 344  0.01484  0.63887  0.01525   g
# 345  0.24590  0.13934  0.48087   g
# 346 -0.10714  0.90546 -0.04307   g
# 347 -0.00035  0.91483  0.04712   g
# 348  0.00442  0.92697 -0.00577   g
# 349 -0.03757  0.87403 -0.16243   g
# 350 -0.06678  0.85764 -0.06151   g
#
# [330 rows x 35 columns]

# %% [markdown]
# ## Encoding categorical columns
#
# The last column i.e column 34 has 2 types of entries: 'g' and 'b', standing for good and bad respectively.
#
# Since the column takes only 2 kinds of values, we can use label encoding to encode the entire column.

# %%
ionosphere_df['34'] = ionosphere_df['34'].replace('g', 1)

# %%
ionosphere_df['34'] = ionosphere_df['34'].replace('b', 0)

# %%
ionosphere_df.head()
# Out:
#    0  1        2        3        4        5        6        7        8  \
# 0  1  0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1  1  0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2  1  0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3  1  0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4  1  0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#          9  ...       25       26       27       28       29       30  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#         31       32       33  34
# 0 -0.54487  0.18641 -0.45300   1
# 1 -0.06288 -0.13738 -0.02447   0
# 2 -0.24180  0.56045 -0.38238   1
# 3  1.00000 -0.32382  1.00000   0
# 4 -0.59573 -0.04608 -0.65697   1
#
# [5 rows x 35 columns]

# %%
cov_mat = np.asarray(ionosphere_df.cov())

# %%
cov_mat.shape
# Out:
# (35, 35)

# %%
print(sum(cov_mat[i].T.dot(cov_mat[i]) < 0 for i in range(len(cov_mat))))
# Out:
# 0

# %% [markdown]
# ## Splitting into train and test sets

# %%
import random

def train_test_split(train_percent, df, id_col):
  random.seed()
  df = df.sample(frac=1).reset_index(drop=True)
  train_set_len = int(train_percent * len(df[id_col]))

  return df.head(train_set_len), df.tail(len(df[id_col]) - train_set_len)

# %%
train_set, test_set = train_test_split(0.8, ionosphere_df, '0')

print("Size of the train set", len(train_set))
print("Size of the test set", len(test_set))
# Out:
# ('Size of the train set', 264)
# ('Size of the test set', 66)

# %%
train_y = np.asarray(train_set['34'])
train_x = np.asarray(train_set.drop(columns = '34'))

# %%
test_y = np.asarray(test_set['34'])
test_x = np.asarray(test_set.drop(columns = '34'))

# %% [markdown]
# ## Gradient Descent

# %%
import math

def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def compute_gradient(x, y, w):
  return sum(x[i] * (sigmoid(w.T.dot(x[i])) - y[i]) for i in range(len(y)))

# %%
def gradient_descent(x, y, epochs, learning_rate):
  w = np.zeros(len(x[0]))

  for epoch in range(epochs):
    
    w = w - (learning_rate * compute_gradient(x, y, w))

  return w

# %%
def predict(x, w):
  return [1 if sigmoid(w.T.dot(x[i])) > 0.5 else 0 for i in range(len(x))]

# %%
def accuracy(pred, y):
  return sum(pred[i] == y[i] for i in range(len(y))) * 1.0 / len(y)

# %%
weights = gradient_descent(train_x, train_y, 20, 0.01)

test_preds = predict(test_x, weights)
train_preds = predict(train_x, weights)

print("Accuracy of the test set:", accuracy(test_preds, test_y))
print("Accuracy of the train set:", accuracy(train_preds, train_y))
# Out:
# ('Accuracy of the test set:', 0.8939393939393939)
# ('Accuracy of the train set:', 0.8787878787878788)

# %% [markdown]
# ## Newton's Method of Optimization

# %%
def double_derivative(x, w, k, j):
  return sum(x[i][j] * x[i][k] * sigmoid(w.T.dot(x[i])) * sigmoid(-w.T.dot(x[i])) for i in range(len(x)))

# %%
def compute_hessian(x, w):
  hessian = [[0 for j in range(len(w))] for i in range(len(w))]

  for i in range(len(w)):
    for j in range(len(w)):
      hessian[i][j] = double_derivative(x, w, i, j)
  
  # print(np.asarray(hessian).shape)
  return hessian

# %%
def newtons_method(x, y, epochs, lambda_correction):
  w = np.zeros(len(x[0]))

  for epoch in range(epochs):
    gradient = compute_gradient(x, y, w)
    hessian = (np.linalg.inv(compute_hessian(x, w) - lambda_correction * 
                           np.identity(34)))
    w = w - hessian.dot(gradient)

  return w

# %%
weights = newtons_method(train_x, train_y, 20, 0.0001)

test_preds = predict(test_x, weights)
train_preds = predict(train_x, weights)

print("Accuracy of the test set:", accuracy(test_preds, test_y))
print("Accuracy of the train set:", accuracy(train_preds, train_y))
# Out:
# ('Accuracy of the test set:', 0.8484848484848485)
# ('Accuracy of the train set:', 0.8939393939393939)

# %% [markdown]
# ## Naive Bayes Classifier

# %%
corr = ionosphere_df.corr()

cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '60px', 'font-size': '10pt'})\
    .set_precision(1)\
# Out:
# /home/vaibhavi/.local/lib/python2.7/site-packages/matplotlib/colors.py:507: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col0 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col1 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col2 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col3 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col4 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col5 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col6 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col7 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col8 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col9 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col10 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col11 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col12 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col13 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col14 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col15 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col16 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col17 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col18 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col19 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col20 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col21 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col22 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col23 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col24 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col25 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col26 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col27 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col28 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col29 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col30 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col31 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col32 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col33 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow0_col34 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow1_col0 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow1_col1 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow1_col2 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow1_col3 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow1_col4 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12d99babfrow1_col5 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_0db9948c_244c_11ec_a35d_34e12

# %% [markdown]
# ### Univariate Guassian
#
# We can take any one of columns 0, 2, 4 or 6 for univariate bayes classifier due to the correlation these columns have on column 34 which is maximum among all other columns.

# %%
import math

def find_gaussian_params(x_column, y_column, df, outcome):
  mean = df[x_column][df[y_column] == outcome].mean()
  std_dev = math.sqrt(df[x_column][df[y_column] == outcome].var())

  return mean, std_dev

# %%
import math

def p_x_given_y(mu, sigma, x):
  # print(sigma)
  return (1 / (sigma * math.sqrt(2 * math.pi))) * math.exp(-0.5 * (((x - mu) / sigma) ** 2))

# %%
def p_y(y_col, n, outcome):
    no_highs = sum(y_col)
    print(no_highs, n)
    return no_highs * 1.0 / n if outcome == 1 else 1 - no_highs * 1.0 / n

# %%
def fit(x_col, y_col, df):
  mean_1, std_dev_1 = find_gaussian_params(x_col, y_col, df, 1)
  mean_0, std_dev_0 = find_gaussian_params(x_col, y_col, df, 0)

  return mean_1, std_dev_1, mean_0, std_dev_0

# %%
def predict(x, probability_c, df, mu_0, sigma_0, mu_1, sigma_1):
  # print("sigma", sigma_1)
  probability_0 = [p_x_given_y(mu_0, sigma_0, x[i]) * probability_c[0] for i in range(len(x))]
  probability_1 = [p_x_given_y(mu_1, sigma_1, x[i]) * probability_c[1] for i in range(len(x))]

  return [0 if probability_0[i] > probability_1[i] else 1 for i in range(len(x))]

# %%
def accuracy(y_pred, y_actual):
  return sum(y_pred[i] == y_actual[i] for i in range(len(y_actual))) * 1.0 / len(y_actual)

# %%
columns_considered = ['0', '2', '4', '6']

print("Mean and Std Deviation for outcome 0")
for column in columns_considered:
  mu, sigma = find_gaussian_params(column, '34', ionosphere_df, 0)
  print(mu, sigma)

print("Mean and Std Deviation for outcome 1")
for column in columns_considered:
  mu, sigma = find_gaussian_params(column, '34', ionosphere_df, 0)
  print(mu, sigma)
# Out:
# Mean and Std Deviation for outcome 0
# (0.6890756302521008, 0.464829094885346)
# (0.30057058823529414, 0.6622126454409145)
# (0.24941873949579832, 0.7003173815257205)
# (0.24371310924369746, 0.6328189176241198)
# Mean and Std Deviation for outcome 1
# (0.6890756302521008, 0.464829094885346)
# (0.30057058823529414, 0.6622126454409145)
# (0.24941873949579832, 0.7003173815257205)
# (0.24371310924369746, 0.6328189176241198)

# %%
possible_columns = [ '2', '4', '6']

probability_c_train = [p_y(train_y, len(train_y), 0), p_y(train_y, len(train_y), 1)]
probability_c_test = [p_y(test_y, len(test_y), 0), p_y(test_y, len(test_y), 1)]

print(probability_c_test)
print(probability_c_train)

for column in possible_columns:
  mean_1, std_dev_1, mean_0, std_dev_0 = fit(column, '34', train_set)

  print("Accuracy of test set for col " + column + " is:", accuracy(predict(np.asarray(test_set[column]), probability_c_train, ionosphere_df, mean_0, std_dev_0, mean_1, std_dev_1), test_y))
  print("Accuracy of train set for col " + column + " is:", accuracy(predict(np.asarray(train_set[column]), probability_c_train, ionosphere_df, mean_0, std_dev_0, mean_1, std_dev_1), train_y))
# Out:
# (164, 264)
# (164, 264)
# (47, 66)
# (47, 66)
# [0.28787878787878785, 0.7121212121212122]
# [0.3787878787878788, 0.6212121212121212]
# ('Accuracy of test set for col 2 is:', 0.7727272727272727)
# ('Accuracy of train set for col 2 is:', 0.7954545454545454)
# ('Accuracy of test set for col 4 is:', 0.803030303030303)
# ('Accuracy of train set for col 4 is:', 0.8143939393939394)
# ('Accuracy of test set for col 6 is:', 0.7727272727272727)
# ('Accuracy of train set for col 6 is:', 0.7916666666666666)

# %% [markdown]
# Since the accuracy is maximum for column 4, we take column 4.

# %% [markdown]
# ## Multivariate Gaussian

# %% [markdown]
# #### Columns to be taken for multivariate Guassian

# %%
## From the correlation matrix we got above the value we predict depends highly on columns: 0, 2, 4, 6

train_x_gnb = train_set[['0', '2', '4', '5', '6', '8', '10', '11', '12', '30']].copy()
test_x_gnb = test_set[['0', '2', '4', '5', '6', '8', '10', '11', '12', '30']].copy()

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, f1_score

# %%
gnb = GaussianNB()

# %%
gnb.fit(train_x_gnb, train_y)

# %%
train_yhat = gnb.predict(train_x_gnb)

# %%
print("Accuracy of the train data", accuracy_score(train_y, train_yhat))
print("f1 score of the train data", f1_score(train_y, train_yhat))

# %%
test_yhat = gnb.predict(test_x_gnb)

# %%
print("Accuracy of the test data", accuracy_score(test_y, test_yhat))
print("f1 score of the test data", f1_score(test_y, test_yhat))
